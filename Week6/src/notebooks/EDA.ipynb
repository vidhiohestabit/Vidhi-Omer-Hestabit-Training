# %%
import pandas as pd

df = pd.read_csv("../data/processed/final.csv")

df.head()
# Out:
#    PassengerId  Survived    Pclass  \
# 0    -1.724991 -0.634429  0.669212
# 1    -1.717290  1.576221  0.669212
# 2    -1.713439  1.576221 -2.122074
# 3    -1.709588 -0.634429  0.669212
# 4    -1.705737 -0.634429  0.669212
#
#                                            Name     Sex       Age     SibSp  \
# 0                       Braund, Mr. Owen Harris    male -0.848100  1.839399
# 1                        Heikkinen, Miss. Laina  female -0.375036 -0.433515
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.689358  1.839399
# 3                      Allen, Mr. William Henry    male  0.689358 -0.433515
# 4                              Moran, Mr. James    male -0.138504 -0.433515
#
#    Parch            Ticket      Fare    Cabin Embarked
# 0    0.0         A/5 21171 -0.613957  B96 B98        S
# 1    0.0  STON/O2. 3101282 -0.549982  B96 B98        S
# 2    0.0            113803  3.731563     C123        S
# 3    0.0            373450 -0.538135  B96 B98        S
# 4    0.0            330877 -0.499438  B96 B98        Q

# %% [markdown]
# # DataSet Info

# %%
df.shape
# Out:
# (561, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  561 non-null    float64
#  1   Survived     561 non-null    float64
#  2   Pclass       561 non-null    float64
#  3   Name         561 non-null    str
#  4   Sex          561 non-null    str
#  5   Age          561 non-null    float64
#  6   SibSp        561 non-null    float64
#  7   Parch        561 non-null    float64
#  8   Ticket       561 non-null    str
#  9   Fare         561 non-null    float64
#  10  Cabin        561 non-null    str
#  11  Embarked     561 non-null    str
# dtypes: float64(7), str(5)
# memory usage: 52.7 KB

# %%
df.describe()
# Out:
#        PassengerId      Survived        Pclass           Age         SibSp  \
# count   561.000000  5.610000e+02  5.610000e+02  5.610000e+02  5.610000e+02
# mean      0.000000 -1.013252e-16 -1.899847e-17 -7.599388e-17  1.013252e-16
# std       1.000892  1.000892e+00  1.000892e+00  1.000892e+00  1.000892e+00
# min      -1.724991 -6.344289e-01 -2.122074e+00 -2.858623e+00 -4.335147e-01
# 25%      -0.877796 -6.344289e-01 -7.264311e-01 -6.115683e-01 -4.335147e-01
# 50%       0.011759 -6.344289e-01  6.692122e-01 -1.385041e-01 -4.335147e-01
# 75%       0.870506  1.576221e+00  6.692122e-01  3.345601e-01 -4.335147e-01
# max       1.702298  1.576221e+00  6.692122e-01  2.936413e+00  4.112312e+00
#
#        Parch          Fare
# count  561.0  5.610000e+02
# mean     0.0  1.203236e-16
# std      0.0  1.000892e+00
# min      0.0 -1.301089e+00
# 25%      0.0 -5.641989e-01
# 50%      0.0 -4.994379e-01
# 75%      0.0  1.253028e-01
# max      0.0  3.731563e+00

# %% [markdown]
# # Missing values

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # Correlation heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %% [markdown]
# # Feature Distribution

# %%
df.hist(figsize=(12,10))
plt.show()

# %% [markdown]
# # Target Distribution

# %%
sns.countplot(x="Survived", data=df)
plt.title("Target Distribution")
plt.show()

# %% [markdown]
# # Missing Values Check

# %%
missing=df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # Missing Values Visualization

# %%
numeric_df = df.select_dtypes(include='number')

if numeric_df.shape[1] > 1:
    plt.figure(figsize=(10,8))
    sns.heatmap(numeric_df.corr(), annot=True)
    plt.show()
else:
    print("Not enough numeric columns for correlation heatmap")
